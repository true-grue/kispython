# %% [markdown]
# # Практическое занятие №1

# %% [markdown]
# Запустите IDLE.
# Проверьте работу интерпретатора на простых арифметических примерах.
# Научитесь создавать новую программу в редакторе IDLE и сохранять ее с расширением `.py`.

# %% [markdown]
# Выясните, есть ли предел в Питоне для вычислений с целыми числами.
# А что насчет чисел с плавающих запятой? Какой диапазон вы сумели получить? Покажите, как вы добились результата с помощью REPL.

# %% [markdown]
# Представим, что в Питоне отсутствует операция умножения. Ее можно заменить сложением. Если мы хотим умножить какое-то число x на 12, то нам понадобится 11 сложений, правильно? Оказывается, можно обойтись меньшим числом сложений.
#
# Попробуйте составить выражения для решения следующих задач. Из арифметических операций можно использовать только явно указанные и в указанном количестве.
#
# 1. Умножение на 12. 4 сложения.
# 1. Умножение на 16. 4 сложения.
# 1. Умножение на 15. 3 сложения и 2 вычитания.
# 1. Умножение на 29. 6 сложений и одно вычитание.

# %% [markdown]
# В реализации Питона спрятано несколько "пасхальных яиц". С одним из них мы уже сталкивались, это `import this`.
# Есть еще одно, как-то связанное с гравитацией. Удастся ли вам его обнаружить? Можете гуглить.

# %% [markdown]
# К сообщениям об ошибках Питона нужно привыкать, в них нет ничего страшного. Давайте специально напишем некорректный код для того, чтобы получить каждое из указанных ниже сообщений об ошибках.
#
# 1. SyntaxError: cannot assign to literal
# 1. SyntaxError: invalid syntax
# 1. NameError: name ... is not defined
# 1. TypeError: unsupported operand type(s) for ...
# 1. IndentationError: expected an indented block
# 1. ZeroDivisionError: division by zero
# 1. ValueError: math domain error
# 1. OverflowError: math range error

# %% [markdown]
# Рассмотрим следующий код:

# %%
0.6 + 0.3 == 0.9
# Out:
# False

# %% [markdown]
# Что здесь произошло? Питон сломался? Обсудите с преподавателем.

# %% [markdown]
# Настало время для решения первой автоматически сгенерированной задачи (pdf-файл, раздел 1). Сначала постарайтесь решить задачу в REPL. Затем перенесите решение в отдельную функцию `f`. Не забудьте протестировать решение на предложенных примерах!
#
# Если вы успешно справились с первой задачей, то приступайте к решению остальных 3 задач. Проконсультируйтесь с преподавателем по поводу того, как в Питоне оформляются условия и циклы.

# %% [markdown]
# Дзен Питона определенно нуждается в толковании. Попробуйте найти в интернете что-нибудь на этот счет и давайте обсудим!
